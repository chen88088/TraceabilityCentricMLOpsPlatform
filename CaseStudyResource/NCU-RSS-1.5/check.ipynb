# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt
import glob
# training/
filenames = glob.glob(r"./data/inference/For_training_testing/320x320/parcel_NIRRGA/3*.npy")
class0 = [x for x in filenames if x.split(" ")[-1]=='0.npy']
class1 = [x for x in filenames if x.split(" ")[-1]=='1.npy']
# print(len(class0))
img = np.load(class0[5])
print(img.shape)
plt.imshow(img[:,:,:3])
plt.show()
plt.imshow(img[:,:,-1])
plt.show()

img = np.load(class1[300])
plt.imshow(img[:,:,:3])
plt.show()
plt.imshow(img[:,:,-1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-3c809bea6984> in <module>
#       8 class1 = [x for x in filenames if x.split(" ")[-1]=='1.npy']
#       9 # print(len(class0))
# ---> 10 img = np.load(class0[5])
#      11 print(img.shape)
#      12 plt.imshow(img[:,:,:3])
#
# IndexError: list index out of range

# %%
# inference
filenames = glob.glob(r"C:\Users\AOIpc\Documents\NCU-RSS-1.5\data\inference\For_training_testing\320x320\parcel_NIRRGA\2\*.npy")
class0 = [x for x in filenames if x.split(" ")[-1]=='0.npy']
class1 = [x for x in filenames if x.split(" ")[-1]=='1.npy']

img = np.load(class0[200])
print(img.shape)
plt.imshow(img[:,:,:3])
plt.show()
plt.imshow(img[:,:,-1])
plt.show()

img = np.load(class1[200])
plt.imshow(img[:,:,:3])
plt.show()
plt.imshow(img[:,:,-1])
plt.show()
# Out:
# (320, 320, 4)
